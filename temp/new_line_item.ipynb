# %%
# Import appropriate modules from the client library.
from googleads import dfp
from collections import defaultdict
from pyspark.sql.types import *
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.functions import expr
from pyspark.sql.functions import *
import pandas as pd
import time
sc.stop()

sc =SparkContext()
sqlCtx = SQLContext(sc)


#connect to the dfp network
from googleads import dfp
dfp_client = dfp.DfpClient.LoadFromStorage()
network_service = dfp_client.GetService('NetworkService', version='v201708')
current_network = network_service.getCurrentNetwork()

# %%
from googleads import dfp


def main(client):
    # Initialize appropriate service.
    line_item_service = client.GetService('LineItemService', version='v201711')

    # Create a statement to select line items.
    statement = dfp.StatementBuilder()

    # Retrieve a small amount of line items at a time, paging
    # through until all line items have been retrieved.
    while True:
        response = line_item_service.getLineItemsByStatement(statement.ToStatement(
        ))
        if 'results' in response:
            for line_item in response['results']:
                # Print out some information for each line item.
   
                if line_item.id == 4389749219 :
                    print('Line item with ID "%d" and name "%s" was found.\n' %
                          (line_item['id'], line_item['name']))
                    print line_item
            statement.offset += statement.limit
        else:
            break

    print '\nNumber of results found: %s' % response['totalResultSetSize']


if __name__ == '__main__':
    # Initialize client object.
    dfp_client = dfp.DfpClient.LoadFromStorage()
    main(dfp_client)
# Out:
# Line item with ID "4389749219" and name "Gojek-CPC-Tangerang-13-44_DN_ID_AND_20170814_2017-API0219_N" was found.
#
# (LineItem){
#    orderId = 2122090049
#    id = 4389749219
#    name = "Gojek-CPC-Tangerang-13-44_DN_ID_AND_20170814_2017-API0219_N"
#    externalId = None
#    orderName = "Gojek_20170814_2017-API0219"
#    startDateTime =
#       (DateTime){
#          date =
#             (Date){
#                year = 2017
#                month = 8
#                day = 14
#             }
#          hour = 7
#          minute = 15
#          second = 0
#          timeZoneID = "America/Toronto"
#       }
#    startDateTimeType = "USE_START_DATE_TIME"
#    endDateTime =
#       (DateTime){
#          date =
#             (Date){
#                year = 2017
#                month = 8
#                day = 19
#             }
#          hour = 12
#          minute = 59
#          second = 0
#          timeZoneID = "America/Toronto"
#       }
#    autoExtensionDays = 0
#    unlimitedEndDateTime = False
#    creativeRotationType = "OPTIMIZED"
#    deliveryRateType = "EVENLY"
#    roadblockingType = "ONE_OR_MORE"
#    frequencyCaps[] =
#       (FrequencyCap){
#          maxImpressions = 1
#          numTimeUnits = 2
#          timeUnit = "DAY"
#       },
#       (FrequencyCap){
#          maxImpressions = 2
#          numTimeUnits = 7
#          timeUnit = "DAY"
#       },
#    lineItemType = "STANDARD"
#    priority = 8
#    costPerUnit =
#       (Money){
#          currencyCode = "IDR"
#          microAmount = 950000000
#       }
#    valueCostPerUnit =
#       (Money){
#          currencyCode = "IDR"
#          microAmount = 0
#       }
#    costType = "CPC"
#    discountType = "PERCENTAGE"
#    discount = 0.0
#    contractedUnitsBought = 0
#    creativePlaceholders[] =
#       (CreativePlaceholder){
#          size =
#             (Size){
#                width = 480
#                height = 320
#                isAspectRatio = False
#             }
#          expectedCreativeCount = 1
#          creativeSizeType = "PIXEL"
#       },
#       (CreativePlaceholder){
#          size =
#             (Size){
#                width = 1200
#                height = 627
#                isAspectRatio = False
#             }
#          expectedCreativeCount = 1
#          creativeSizeType = "PIXEL"
#       },
#       (CreativePlaceholder){
#          size =
#             (Size){
#                width = 300
#                height = 250
#                isAspectRatio = False
#             }
#          expectedCreativeCount = 1
#          creativeSizeType = "PIXEL"
#       },
#    environmentType = "BROWSER"
#    companionDeliveryOption = "UNKNOWN"
#    creativePersistenceType = "NOT_PERSISTENT"
#    allowOverbook = False
#    skipInventoryCheck = False
#    skipCrossSellingRuleWarningChecks = False
#    reserveAtCreation = False
#    stats =
#       (Stats){
#          impressionsDelivered = 251634
#          clicksDelivered = 3986
#          videoCompletionsDelivered = 0
#          videoStartsDelivered = 0
#          viewableImpressionsDelivered = 0
#       }
#    deliveryIndicator =
#       (DeliveryIndicator){
#          expectedDeliveryPercentage = 100.0
#          actualDeliveryPercentage = 87.9135421262
#       }
#    budget =
#       (Money){
#          currencyCode = "IDR"
#          microAmount = 4307300000000
#       }
#    status = "COMPLETED"
#    reservationStatus = "RESERVED"
#    isArchived = False
#    webPropertyCode = None
#    disableSameAdvertiserCompetitiveExclusion = False
#    lastModifiedByApp = "Goog_DFPUI"
#    notes = "9,000 clicks moved to Jakarta AND item per Dian's req. on 0814
# Freq cap changed to 1/2 days and 2/7 days per Didit's req. on 0815
# Banten city targeting added per Didit req. on 0815
# 283 clicks have been relocated from IOS to AND line per Dian`s req 08/16
# 412 clicks have been relocated from Depok IOS to tangerang AND line per Dian`s req 08/16
# 50 clicks have been relocated from IOS to AND line per Didit`s req 08/17
# "
#    lastModifiedDateTime =
#       (DateTime){
#          date =
#             (Date){
#                year = 2017
#                month = 8
#                day = 17
#             }
#          hour = 1
#          minute = 6
#          second = 45
#          timeZoneID = "PST8PDT"
#       }
#    creationDateTime =
#       (DateTime){
#          date =
#             (Date){
#                year = 2017
#                month = 8
#                day = 14
#             }
#          hour = 7
#          minute = 12
#          second = 57
#          timeZoneID = "America/Toronto"
#       }
#    isPrioritizedPreferredDealsEnabled = False
#    adExchangeAuctionOpeningPriority = 0
#    customFieldValues[] =
#       (CustomFieldValue){
#          customFieldId = 7716
#          value =
#             (BooleanValue){
#                value = True
#             }
#       },
#       (CustomFieldValue){
#          customFieldId = 6876
#          value =
#             (TextValue){
#                value = "kopt-aplikasi-gojek-and-108d"
#             }
#       },
#       (CustomFieldValue){
#          customFieldId = 18156
#          value =
#             (BooleanValue){
#                value = True
#             }
#       },
#       (DropDownCustomFieldValue){
#          customFieldId = 8196
#          customFieldOptionId = 20436
#       },
#       (DropDownCustomFieldValue){
#          customFieldId = 7956
#          customFieldOptionId = 20196
#       },
#    isSetTopBoxEnabled = False
#    isMissingCreatives = False
#    videoMaxDuration = 0
#    primaryGoal =
#       (Goal){
#          goalType = "LIFETIME"
#          unitType = "CLICKS"
#          units = 4534
#       }
#    targeting =
#       (Targeting){
#          geoTargeting =
#             (GeoTargeting){
#                targetedLocations[] =
#                   (Location){
#                      id = 9056637
#                      type = "PROVINCE"
#                      canonicalParentId = 2360
#                      displayName = "Banten"
#                   },
#             }
#          inventoryTargeting =
#             (InventoryTargeting){
#                targetedAdUnits[] =
#                   (AdUnitTargeting){
#                      adUnitId = "90952716"
#                      includeDescendants = True
#                   },
#             }
#          technologyTargeting =
#             (TechnologyTargeting){
#                operatingSystemTargeting =
#                   (OperatingSystemTargeting){
#                      isTargeted = True
#                      operatingSystems[] =
#                         (OperatingSystem){
#                            id = 501013
#                            name = "Android"
#                         },
#                   }
#                operatingSystemVersionTargeting =
#                   (OperatingSystemVersionTargeting){
#                      excludedOperatingSystemVersions[] =
#                         (OperatingSystemVersion){
#                            id = 630184
#                            name = "Android 1.6.x"
#                            majorVersion = 1
#                            minorVersion = 6
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630186
#                            name = "Android 2.0.x"
#                            majorVersion = 2
#                            minorVersion = 0
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630221
#                            name = "Android 2.3.x"
#                            majorVersion = 2
#                            minorVersion = 3
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630188
#                            name = "Android 2.1.x"
#                            majorVersion = 2
#                            minorVersion = 1
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630223
#                            name = "Android 3.0.x"
#                            majorVersion = 3
#                            minorVersion = 0
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630190
#                            name = "Android 2.2.x"
#                            majorVersion = 2
#                            minorVersion = 2
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630225
#                            name = "Android 3.1.x"
#                            majorVersion = 3
#                            minorVersion = 1
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630176
#                            name = "Android 0.5.x"
#                            majorVersion = 0
#                            minorVersion = 5
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630227
#                            name = "Android 3.2.x"
#                            majorVersion = 3
#                            minorVersion = 2
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630178
#                            name = "Android 1.0.x"
#                            majorVersion = 1
#                            minorVersion = 0
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630180
#                            name = "Android 1.1.x"
#                            majorVersion = 1
#                            minorVersion = 1
#                            microVersion = -1
#                         },
#                         (OperatingSystemVersion){
#                            id = 630182
#                            name = "Android 1.5.x"
#                            majorVersion = 1
#                            minorVersion = 5
#                            microVersion = -1
#                         },
#                   }
#             }
#          customTargeting =
#             (CustomCriteriaSet){
#                logicalOperator = "OR"
#                children[] =
#                   (CustomCriteriaSet){
#                      logicalOperator = "AND"
#                      children[] =
#                         (CustomCriteria){
#                            keyId = 361596
#                            valueIds[] =
#                               138540114756,
#                               138540114516,
#                               138540114996,
#                               138540114276,
#                            operator = "IS"
#                         },
#                         (CustomCriteria){
#                            keyId = 368196
#                            valueIds[] =
#                               140963284836,
#                            operator = "IS"
#                         },
#                         (AudienceSegmentCriteria){
#                            operator = "IS_NOT"
#                            audienceSegmentIds[] =
#                               492960020,
#                         },
#                   },
#             }
#       }
#  }
# Number of results found: 36535
